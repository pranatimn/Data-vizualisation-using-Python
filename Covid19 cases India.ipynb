# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Get data

# %%
df = pd.read_csv("raw_data1.csv")

# %%
df.head()
# Out:
#    Patient Number State Patient Number Date Announced  Estimated Onset Date  \
# 0             1.0             KL-TS-P1     30/01/2020                   NaN
# 1             2.0             KL-AL-P1     02/02/2020                   NaN
# 2             3.0             KL-KS-P1     03/02/2020                   NaN
# 3             4.0                DL-P1     02/03/2020                   NaN
# 4             5.0                TS-P1     02/03/2020                   NaN
#
#   Age Bracket Gender             Detected City Detected District  \
# 0          20      F                  Thrissur          Thrissur
# 1         NaN    NaN                 Alappuzha         Alappuzha
# 2         NaN    NaN                 Kasaragod         Kasaragod
# 3          45      M  East Delhi (Mayur Vihar)        East Delhi
# 4          24      M                 Hyderabad         Hyderabad
#
#   Detected State State code  ...  \
# 0         Kerala         KL  ...
# 1         Kerala         KL  ...
# ...

# %%
data = df.iloc[:,:]
data
# Out:
#        Patient Number State Patient Number Date Announced  \
# 0                 1.0             KL-TS-P1     30/01/2020
# 1                 2.0             KL-AL-P1     02/02/2020
# 2                 3.0             KL-KS-P1     03/02/2020
# 3                 4.0                DL-P1     02/03/2020
# 4                 5.0                TS-P1     02/03/2020
# ...               ...                  ...            ...
# 17359             NaN                  NaN     16/04/2020
# 17360             NaN                  NaN     18/04/2020
# 17361             NaN                  NaN     18/04/2020
# 17362             NaN                  NaN     19/04/2020
# 17363             NaN                  NaN     19/04/2020
#
#        Estimated Onset Date Age Bracket Gender             Detected City  \
# 0                       NaN          20      F                  Thrissur
# 1                       NaN         NaN    NaN                 Alappuzha
# ...

# %% [markdown]
# # Inspect the dataframe

# %%
data.info
# Out:
# <bound method DataFrame.info of        Patient Number State Patient Number Date Announced  \
# 0                 1.0             KL-TS-P1     30/01/2020
# 1                 2.0             KL-AL-P1     02/02/2020
# 2                 3.0             KL-KS-P1     03/02/2020
# 3                 4.0                DL-P1     02/03/2020
# 4                 5.0                TS-P1     02/03/2020
# ...               ...                  ...            ...
# 17359             NaN                  NaN     16/04/2020
# 17360             NaN                  NaN     18/04/2020
# 17361             NaN                  NaN     18/04/2020
# 17362             NaN                  NaN     19/04/2020
# 17363             NaN                  NaN     19/04/2020
#
#        Estimated Onset Date Age Bracket Gender             Detected City  \
# 0                       NaN          20      F                  Thrissur
# 1                       NaN         NaN    NaN                 Alappuzha
# ...

# %% [markdown]
# # Inspect null values in each column

# %%
round(data.isnull().sum().sort_values(ascending=False)/len(data)*100,2)
# Out:
# Estimated Onset Date                         100.00
# Backup Notes                                  97.92
# Source_3                                      97.44
# Contracted from which Patient (Suspected)     91.15
# Nationality                                   91.05
# Age Bracket                                   90.38
# Detected City                                 87.53
# State Patient Number                          85.85
# Type of transmission                          83.01
# Source_2                                      80.44
# Gender                                        78.43
# Detected District                             13.74
# Notes                                          7.59
# Source_1                                       1.66
# Status Change Date                             0.97
# Patient Number                                 0.33
# Detected State                                 0.01
# State code                                     0.01
# ...

# %% [markdown]
# # Inspect null values in each row

# %%
data.isnull().sum(axis=1).sort_values(ascending= False)
# Out:
# 4375     16
# 17363    15
# 17325    15
# 17339    15
# 17337    15
#          ..
# 267       1
# 56        1
# 55        1
# 266       1
# 38        1
# Length: 17364, dtype: int64

# %% [markdown]
# # Total No of Covid-19 Corona Virus Patient in India Gender wise

# %%
data.groupby('Gender')['Num Cases'].sum()
# Out:
# Gender
# F    1223
# M    2523
# Name: Num Cases, dtype: int64

# %% [markdown]
# # Which age group is affected the most

# %%
M = data.groupby('Age Bracket')['Num Cases'].sum().sort_values(ascending= False).head(10)
M
# Out:
# Age Bracket
# 35    67
# 32    52
# 40    49
# 55    45
# 50    44
# 45    43
# 21    42
# 65    41
# 26    39
# 27    38
# Name: Num Cases, dtype: int64

# %%
M.plot.bar()
plt.show()

# %% [markdown]
# # Total No of Covid-19 Corona Virus Patient in India State wise

# %%
M = data.groupby('Detected State')['Num Cases'].sum().sort_values(ascending=False)
M
# Out:
# Detected State
# Maharashtra                    4200
# Delhi                          2003
# Gujarat                        1743
# Rajasthan                      1478
# Tamil Nadu                     1477
# Madhya Pradesh                 1407
# Uttar Pradesh                  1100
# Telangana                       858
# Andhra Pradesh                  647
# Kerala                          402
# Karnataka                       390
# Jammu and Kashmir               354
# West Bengal                     310
# Haryana                         250
# Punjab                          244
# Bihar                            96
# Odisha                           61
# Uttarakhand                      44
# Jharkhand                        41
# Himachal Pradesh                 39
# Chhattisgarh                     36
# Assam                            35
# Chandigarh                       26
# Ladakh                           18
# Andaman and Nicobar Islands      15
# ...

# %%
M.plot.bar(figsize=(15,5))
plt.show()
